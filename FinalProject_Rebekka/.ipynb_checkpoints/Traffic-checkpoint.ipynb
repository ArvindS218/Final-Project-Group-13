# %% [markdown]
# **This is the traffic analysis for what neighborhood in Pittsburgh is the best to commit *arson***\
# by Rebekka Hubrich

# %%
import pandas as pd
import numpy as np

# %%
traffic_data = pd.read_csv("https://data.wprdc.org/datastore/dump/6dfd4f8f-cbf5-4917-a5eb-fd07f4403167")
traffic_data.head()
# Out:
#    _id          id  device_id    record_oid count_start_date count_end_date  \
# 0    1  1011743669         85  1.445865e+09       2019-04-18     2019-04-26
# 1    2  1026101993        140  1.121444e+09       2019-01-24            NaN
# 2    3  1032382575         11  1.539893e+09       2018-08-28     2018-09-04
# 3    4   103627606          9  7.341951e+08       2018-07-17     2018-08-01
# 4    5  1039546167        144           NaN              NaN            NaN
#
#    average_daily_car_traffic  average_daily_bike_traffic counter_number  \
# 0                     4949.0                         NaN              6
# 1                        NaN                         NaN            NaN
# 2                        NaN                         NaN            NaN
# 3                     2741.0                         NaN            NaN
# 4                        NaN                         NaN            NaN
#
#          counter_type  ...  longitude   latitude           neighborhood  \
# ...

# %%
#query_mask = traffic_data['average_daily_car_traffic']!=nan
#graph = pd.DataFrame(columns=traffic_data['average_daily_car_traffic'],index=traffic_data['neighborhood'])
#graph.plot(kind='bar')

query_mask = traffic_data['average_daily_car_traffic']>7000
hehehawhaw = traffic_data[query_mask]
#hehehawhaw.head(40)
final = dict()
for row in hehehawhaw[1:]:
    if row[18] not in final:
        final[row[18]] = row[7]
    else:
        final[row[18]] = final[row[18]]+row[7]
final 

        
        
#hehehawhaw['average_daily_car_traffic'].plot(x='neighborhoods')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-25-81daabe2d63b> in <module>
#       8 final = dict()
#       9 for row in hehehawhaw:
# ---> 10     if row[18] not in final:
#      11         final[row[18]] = row[7]
#      12     else:
#
# IndexError: string index out of range
